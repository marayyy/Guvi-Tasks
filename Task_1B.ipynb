# %% [markdown]
# <a href="https://colab.research.google.com/github/marayyy/GUVI-mentor-task/blob/main/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fetching data from mflix

# %% [markdown]
# connect to mongodb server

# %%
from pymongo import MongoClient

# %% [markdown]
# login using acess details

# %%
raj=MongoClient("mongodb://maray24021999:Mongo@ac-wiomlrs-shard-00-00.fkrzenv.mongodb.net:27017,ac-wiomlrs-shard-00-01.fkrzenv.mongodb.net:27017,ac-wiomlrs-shard-00-02.fkrzenv.mongodb.net:27017/?ssl=true&replicaSet=atlas-ievdfb-shard-0&authSource=admin&retryWrites=true&w=majority")

# %% [markdown]
# Driver code

# %%
r1 = raj['sample_mflix']

# %%
a1 = r1['movies']

# %%
for i in a1.find({'year':{'$lt':1900}}):
  print(i)
# Out:
# {'_id': ObjectId('573a1390f29313caabcd4135'), 'plot': 'Three men hammer on an anvil and pass a bottle of beer around.', 'genres': ['Short'], 'runtime': 1, 'cast': ['Charles Kayser', 'John Ott'], 'num_mflix_comments': 0, 'title': 'Blacksmith Scene', 'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.', 'countries': ['USA'], 'released': datetime.datetime(1893, 5, 9, 0, 0), 'directors': ['William K.L. Dickson'], 'rated': 'UNRATED', 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-08-26 00:03:50.133000000', 'year': 1893, 'imdb': {'rating': 6.2, 'votes': 1189, 'id': 5}, 'type': 'movie', 'tomatoes': 
# ...

# %%
for i in a1.find({'year':{'$lt':1900}},{"_id":0}):
  print(i)
# Out:
# {'plot': 'Three men hammer on an anvil and pass a bottle of beer around.', 'genres': ['Short'], 'runtime': 1, 'cast': ['Charles Kayser', 'John Ott'], 'num_mflix_comments': 0, 'title': 'Blacksmith Scene', 'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.', 'countries': ['USA'], 'released': datetime.datetime(1893, 5, 9, 0, 0), 'directors': ['William K.L. Dickson'], 'rated': 'UNRATED', 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-08-26 00:03:50.133000000', 'year': 1893, 'imdb': {'rating': 6.2, 'votes': 1189, 'id': 5}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 184,
# ...

# %%
for i in a1.find({'year':{'$lt':1900}},{"_id":0,"title":1}):
  print(i)
# Out:
# {'title': 'Blacksmith Scene'}
# {'title': 'The Kiss'}
# {'title': 'Dickson Experimental Sound Film'}
# {'title': 'The Kiss'}
# {'title': 'Newark Athlete'}

# %%
L1 = []
for i in a1.find({'year':{'$lt':1900}},{"_id":0}):
  L1.append(i)

# %%
print(L1)
# Out:
# [{'plot': 'Three men hammer on an anvil and pass a bottle of beer around.', 'genres': ['Short'], 'runtime': 1, 'cast': ['Charles Kayser', 'John Ott'], 'num_mflix_comments': 0, 'title': 'Blacksmith Scene', 'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.', 'countries': ['USA'], 'released': datetime.datetime(1893, 5, 9, 0, 0), 'directors': ['William K.L. Dickson'], 'rated': 'UNRATED', 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-08-26 00:03:50.133000000', 'year': 1893, 'imdb': {'rating': 6.2, 'votes': 1189, 'id': 5}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 184
# ...

# %% [markdown]
# Data Frame

# %%
DF1 = pd.DataFrame(L1)
DF1
# Out:
#                                                 plot                genres  \
# 0  Three men hammer on an anvil and pass a bottle...               [Short]
# 1                                   Two people kiss.      [Short, Romance]
# 2  The sound has been found in the form of an old...               [Short]
# 3                                   Two people kiss.      [Short, Romance]
# 4                    An athlete swings Indian clubs.  [Documentary, Short]
#
#    runtime                        cast  num_mflix_comments  \
# 0        1  [Charles Kayser, John Ott]                   0
# 1        1   [May Irwin, John C. Rice]                   0
# 2        1      [William K.L. Dickson]                   0
# 3        1   [May Irwin, John C. Rice]                   1
# 4        1                         NaN                   1
#
#                              title  \
# 0                 Blacksmith Scene
# 1                         The Kiss
# 2  Dickson Experimental Sound Film
# ...

# %%
for i in a1.find({"$and":[{"tomatoes.viewer.rating":{"$gt":3}},{"imdb.rating":{"$gt":7}}]},{"_id":0,"tomatoes.views.rating":1,"title":1,"Director.names":1,"imdb.rating":1,"cast":1}):
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# {'imdb': {'rating': 7.4}, 'title': 'Beetlejuice', 'tomatoes': {}, 'cast': ['Alec Baldwin', 'Geena Davis', 'Annie McEnroe', 'Maurice Page']}
# {'cast': ['Tom Hanks', 'Elizabeth Perkins', 'Robert Loggia', 'John Heard'], 'title': 'Big', 'imdb': {'rating': 7.3}, 'tomatoes': {}}
# {'imdb': {'rating': 7.1}, 'title': 'Bull Durham', 'tomatoes': {}, 'cast': ['Kevin Costner', 'Susan Sarandon', 'Tim Robbins', 'Trey Wilson']}
# {'cast': ['Luès Miguel Cintra', 'Leonor Silveira', 'Diogo Dèria', 'Oliveira Lopes'], 'title': 'Os Canibais', 'imdb': {'rating': 7.2}, 'tomatoes': {}}
# {'cast': ['Christina Applegate', 'Tempestt Bledsoe', 'Brian Bloom', 'Cliff De Young'], 'title': "Dance 'Til Dawn", 'imdb': {'rating': 7.1}, 'tomatoes': {}}
# {'cast': ['Aleksei Ananishnov', 'Eskender Umarov', 'Irina Sokolova', 'Vladimir Zamanskiy'], 'title': 'Days of Eclipse', 'imdb': {'rating': 7.4}, 'tomatoes': {}}
# ...

# %%
L2 = []
for i in a1.find({'year':{'$lt':1900}},{"_id":0}):
  L2.append(i)

# %%
print(L2)
# Out:
# [{'plot': 'Three men hammer on an anvil and pass a bottle of beer around.', 'genres': ['Short'], 'runtime': 1, 'cast': ['Charles Kayser', 'John Ott'], 'num_mflix_comments': 0, 'title': 'Blacksmith Scene', 'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.', 'countries': ['USA'], 'released': datetime.datetime(1893, 5, 9, 0, 0), 'directors': ['William K.L. Dickson'], 'rated': 'UNRATED', 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-08-26 00:03:50.133000000', 'year': 1893, 'imdb': {'rating': 6.2, 'votes': 1189, 'id': 5}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 184
# ...

# %%
DF1 = pd.DataFrame(L2)
DF1
# Out:
#                                                 plot                genres  \
# 0  Three men hammer on an anvil and pass a bottle...               [Short]
# 1                                   Two people kiss.      [Short, Romance]
# 2  The sound has been found in the form of an old...               [Short]
# 3                                   Two people kiss.      [Short, Romance]
# 4                    An athlete swings Indian clubs.  [Documentary, Short]
#
#    runtime                        cast  num_mflix_comments  \
# 0        1  [Charles Kayser, John Ott]                   0
# 1        1   [May Irwin, John C. Rice]                   0
# 2        1      [William K.L. Dickson]                   0
# 3        1   [May Irwin, John C. Rice]                   1
# 4        1                         NaN                   1
#
#                              title  \
# 0                 Blacksmith Scene
# 1                         The Kiss
# 2  Dickson Experimental Sound Film
# ...
